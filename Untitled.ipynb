# %%
import yfinance as yf
# print(dir(yf.download))
yf.download('tcs')
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2013-11-01  35.000000  37.000000  32.099998  36.200001  33.839130  14667600
# 2013-11-04  36.799999  36.799999  34.689999  35.349998  33.044563   1586600
# 2013-11-05  35.110001  35.500000  34.820000  35.349998  33.044563    337700
# 2013-11-06  35.610001  36.490002  35.610001  35.900002  33.558697    549600
# 2013-11-07  36.799999  36.799999  34.119999  35.310001  33.007175    883700
# ...               ...        ...        ...        ...        ...       ...
# 2023-10-25   1.990000   1.990000   1.870000   1.870000   1.870000    429600
# 2023-10-26   1.860000   1.890000   1.790000   1.820000   1.820000    417900
# 2023-10-27   1.850000   1.900000   1.810000   1.860000   1.860000    184800
# 2023-10-30   1.860000   1.900000   1.830000   1.840000   1.840000    234300
# ...

# %%
data = yf.download('infy', period="1mo")
data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2023-10-02  17.030001  17.190001  17.030001  17.180000  16.958851   4529900
# 2023-10-03  17.090000  17.240000  16.980000  17.000000  16.781168   6775000
# 2023-10-04  17.190001  17.450001  17.160000  17.440001  17.215506   7318800
# 2023-10-05  17.520000  17.650000  17.459999  17.610001  17.383316   5069500
# 2023-10-06  17.590000  17.860001  17.540001  17.790001  17.561001   5476600
# 2023-10-09  17.580000  17.799999  17.530001  17.750000  17.521513   8642700
# 2023-10-10  17.850000  18.000000  17.780001  17.850000  17.620228  11060900
# 2023-10-11  17.860001  17.930000  17.549999  17.610001  17.383316  15897100
# 2023-10-12  16.400000  16.889999  16.209999  16.459999  16.248119  26816400
# 2023-10-13  16.840000  17.190001  16.770000  16.900000  16.682455  13208800
# ...

# %%
tickerSymbol = 'tcs'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get the historical prices for this ticker
tickerDf = tickerData.history(period='1d', start='2023-1-1', end='2023-1-25')

#see your data
tickerDf
# Out:
#                            Open  High   Low  Close  Volume  Dividends  \
# Date
# 2023-01-03 00:00:00-05:00  4.40  4.49  4.33   4.43  308700        0.0
# 2023-01-04 00:00:00-05:00  4.46  4.67  4.44   4.64  350700        0.0
# 2023-01-05 00:00:00-05:00  4.65  4.65  4.48   4.54  173800        0.0
# 2023-01-06 00:00:00-05:00  4.63  4.70  4.55   4.67  150100        0.0
# 2023-01-09 00:00:00-05:00  4.74  4.92  4.66   4.83  278900        0.0
# 2023-01-10 00:00:00-05:00  4.83  4.98  4.83   4.96  158400        0.0
# 2023-01-11 00:00:00-05:00  4.97  5.14  4.97   5.14  255200        0.0
# 2023-01-12 00:00:00-05:00  5.15  5.35  5.12   5.34  484400        0.0
# 2023-01-13 00:00:00-05:00  5.29  5.38  5.18   5.24  436600        0.0
# 2023-01-17 00:00:00-05:00  5.26  5.30  5.14   5.16  246400        0.0
# 2023-01-18 00:00:00-05:00  5.18  5.26  4.95   4.95  266400        0.0
# 2023-01-19 00:00:00-05:00  4.91  4.99  4.72   4.80  226900        0.0
# ...

# %%
ticker = yf.Ticker('infy').info
marketPrice = ticker['regularMarketPrice']
previousClosePrice = ticker['regularMarketPreviousClose']
print('Ticker Value: GOOGL')
print('Market Price Value:', marketPrice)
print('Previous Close Price Value:', previousClosePrice)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# d:\OneDrive\New folder_python\Djangoprojects\Turtle_trading\Untitled.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive/New%20folder_python/Djangoprojects/Turtle_trading/Untitled.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> ticker = yf.Ticker('infy').info
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/New%20folder_python/Djangoprojects/Turtle_trading/Untitled.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> marketPrice = ticker['regularMarketPrice']
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/New%20folder_python/Djangoprojects/Turtle_trading/Untitled.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> previousClosePrice = ticker['regularMarketPreviousClose']
#
# File d:\OneDrive\New folder_python\Djangoprojects\Turtle_trading\turtle_trad_env\Lib\site-packages\yfinance\ticker.py:142, in Ticker.info(self)
#     140 @property
# ...

# %%
yf.download('tcs',period='1mo')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['TCS']: Exception('%ticker%: No price data found, symbol may be delisted (period=1mo)')
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
d = yf.download('tcs', period='1mo')
d
# Out:
# [*********************100%%**********************]  1 of 1 completed
#             Open  High     Low  Close  Adj Close  Volume
# Date
# 2023-10-02  2.22  2.28  2.1500   2.21       2.21  725700
# 2023-10-03  2.18  2.26  2.1500   2.15       2.15  411500
# 2023-10-04  2.16  2.26  2.1200   2.18       2.18  395000
# 2023-10-05  2.14  2.17  1.9500   2.03       2.03  656100
# 2023-10-06  2.00  2.19  2.0000   2.11       2.11  396200
# 2023-10-09  2.05  2.08  1.9700   2.02       2.02  299100
# 2023-10-10  2.02  2.16  2.0000   2.10       2.10  269200
# 2023-10-11  2.11  2.17  2.0200   2.05       2.05  190900
# 2023-10-12  2.07  2.08  1.9600   2.01       2.01  240600
# 2023-10-13  2.01  2.06  1.9600   2.03       2.03  163700
# 2023-10-16  2.01  2.13  2.0000   2.08       2.08  228200
# 2023-10-17  2.05  2.23  2.0400   2.20       2.20  273300
# 2023-10-18  2.18  2.21  2.1300   2.17       2.17  122600
# 2023-10-19  2.16  2.21  2.1300   2.15       2.15  189800
# ...

# %%
tickerSymbol = 'wipro'

#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get the historical prices for this ticker
tickerDf = tickerData.history(period='1d', start='2023-1-1', end='2023-1-25')

#see your data
tickerDf
# Out:
# WIPRO: No timezone found, symbol may be delisted
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
yf.download('WIPRO', period="1mo")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# 1 Failed download:
# ['WIPRO']: Exception('%ticker%: No data found, symbol may be delisted')
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
from nsetools import Nse

nse = Nse()
all_stock_codes = nse.get_stock_codes()

for code, name in all_stock_codes.items():
    print(f"{code}: {name}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# d:\OneDrive\New folder_python\Djangoprojects\Turtle_trading\Untitled.ipynb Cell 9 line 4
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/New%20folder_python/Djangoprojects/Turtle_trading/Untitled.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> from nsetools import Nse
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/New%20folder_python/Djangoprojects/Turtle_trading/Untitled.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> nse = Nse()
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive/New%20folder_python/Djangoprojects/Turtle_trading/Untitled.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> all_stock_codes = nse.get_stock_codes()
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/New%20folder_python/Djangoprojects/Turtle_trading/Untitled.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> for code, name in all_stock_codes.items():
# ...

# %%
# !pip install --upgrade nsetools
# Out:
# Requirement already up-to-date: nsetools in d:\onedrive\new folder_python\djangoprojects\turtle_trading\turtle_trad_env\lib\site-packages (1.0.11)
# ...
# WARNING: You are using pip version 20.0.2; however, version 23.3.1 is available.
# You should consider upgrading via the 'D:\OneDrive\New folder_python\Djangoprojects\Turtle_trading\turtle_trad_env\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
yf.get_tickers_sp500()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\OneDrive\New folder_python\Djangoprojects\Turtle_trading\Untitled.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive/New%20folder_python/Djangoprojects/Turtle_trading/Untitled.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> yf.get_tickers_sp500()
#
# AttributeError: module 'yfinance' has no attribute 'get_tickers_sp500'

# %%
def IsPerfect(arr):
    #Complete the function
    for i in range(len(arr)//2):
        print(arr[i])
        print(arr[-(i+1)])
        if arr[i] != arr[-(i+1)]:
            return "NOT PERFECT"
    else:
        return "PERFECT"   

IsPerfect([1,2,3,2])
# Out:
# 1
# 2
# 'NOT PERFECT'
